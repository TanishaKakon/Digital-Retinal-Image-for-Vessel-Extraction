# %%
import numpy as np 
import pandas as pd 
import os
import glob
import cv2
import random
import sys
import shutil
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from os import path
from PIL import Image
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import optimizers
from keras.utils import to_categorical, plot_model
from keras.layers import Dense, Input, Conv2D, Flatten, MaxPooling2D, Activation
from keras.models import Model, Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam, SGD, RMSprop
from keras.applications.vgg16 import VGG16
from keras.models import load_model
from keras.utils import np_utils

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
import pandas as pd
# Out:
# Using TensorFlow backend.
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
PATH = 'ChaseDB/training/manual'
mask=glob.glob(os.path.join(PATH,'L','*.png'))

# %%
i=1
for file in mask:
    img = cv2.imread('C:/Users/subah/fcn/ChaseDB/training/manual/L/Image_'+str(i)+'L_1stHO.png')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ChaseDB/training/1st_manual/Image_'+str(i)+'L_1stHO.png', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (960, 999, 3)

# %%
PATH = 'ChaseDB/training/manual'
mask=glob.glob(os.path.join(PATH,'R','*.png'))

# %%
i=1
for file in mask:
    img = cv2.imread('C:/Users/subah/fcn/ChaseDB/training/manual/R/Image_'+str(i)+'R_1stHO.png')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ChaseDB/training/1st_manual/Image_'+str(i)+'R_1stHO.png', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (960, 999, 3)

# %%
PATH = 'ChaseDB/training'

# %%
images=glob.glob(os.path.join(PATH,'images','*.jpg'))
mask=glob.glob(os.path.join(PATH,'1st_manual','*.png'))
if not os.path.exists('./ChaseDB/training/output_images'):
    os.makedirs('./ChaseDB/training/output_images')
if not os.path.exists('./ChaseDB/training/output_1st_manual'):
    os.makedirs('./ChaseDB/training/output_1st_manual')
src = "./ChaseDB/training/images/"
dst = "./ChaseDB/training/output_images/"
src1= "./ChaseDB/training/1st_manual/"
dst1 = "./ChaseDB/training/output_1st_manual/"

# %%
cropheight=350
cropwidth = 350
k=-1
for file in images:
    k+=1
    im = Image.open(images[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (images[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (images[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# ChaseDB/training\images\Image_01L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_01L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_01L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_01L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_01L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_01L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_01L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_01L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_01L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_01R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_01R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_01R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_01R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_01R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_01R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_01R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_01R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_01R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_02L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_02L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_02L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_02L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_02L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_02L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_02L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_02L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_02L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_02R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_02R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_02R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_02R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_02R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_02R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_02R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_02R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_02R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_03L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_03L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_03L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_03L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_03L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_03L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_03L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_03L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_03L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_03R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_03R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_03R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_03R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_03R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_03R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_03R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_03R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_03R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_04L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_04L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_04L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_04L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_04L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_04L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_04L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_04L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_04L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_04R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_04R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_04R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_04R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_04R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_04R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_04R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_04R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_04R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_05L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_05L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_05L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_05L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_05L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_05L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_05L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_05L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_05L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_05R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_05R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_05R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_05R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_05R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_05R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_05R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_05R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_05R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_06L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_06L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_06L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_06L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_06L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_06L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_06L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_06L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_06L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_06R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_06R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_06R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_06R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_06R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_06R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_06R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_06R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_06R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_07L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_07L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_07L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_07L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_07L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_07L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_07L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_07L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_07L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_07R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_07R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_07R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_07R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_07R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_07R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_07R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_07R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_07R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_08L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_08L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_08L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_08L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_08L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_08L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_08L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_08L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_08L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_08R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_08R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_08R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_08R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_08R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_08R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_08R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_08R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_08R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_09L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_09L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_09L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_09L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_09L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_09L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_09L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_09L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_09L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_09R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_09R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_09R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_09R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_09R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_09R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_09R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_09R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_09R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_10L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_10L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_10L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_10L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_10L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_10L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_10L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_10L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_10L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_10R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_10R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_10R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_10R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_10R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_10R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_10R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_10R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_10R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_11L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_11L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_11L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_11L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_11L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_11L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_11L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_11L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_11L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_11R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_11R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_11R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_11R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_11R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_11R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_11R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_11R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_11R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_12L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_12L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_12L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_12L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_12L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_12L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_12L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_12L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_12L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_12R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_12R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_12R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_12R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_12R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_12R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_12R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_12R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_12R.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_13L.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_13L.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_13L.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_13L.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_13L.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_13L.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_13L.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_13L.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_13L.jpg (700, 700, 1050, 1050)
# ChaseDB/training\images\Image_13R.jpg (0, 0, 350, 350)
# ChaseDB/training\images\Image_13R.jpg (0, 350, 350, 700)
# ChaseDB/training\images\Image_13R.jpg (0, 700, 350, 1050)
# ChaseDB/training\images\Image_13R.jpg (350, 0, 700, 350)
# ChaseDB/training\images\Image_13R.jpg (350, 350, 700, 700)
# ChaseDB/training\images\Image_13R.jpg (350, 700, 700, 1050)
# ChaseDB/training\images\Image_13R.jpg (700, 0, 1050, 350)
# ChaseDB/training\images\Image_13R.jpg (700, 350, 1050, 700)
# ChaseDB/training\images\Image_13R.jpg (700, 700, 1050, 1050)

# %%
cropheight=350
cropwidth = 350
k=-1
for file in mask:
    k+=1
    im = Image.open(mask[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (mask[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tif' % (mask[k], i, j))
       files = [i for i in os.listdir(src1) if i.endswith(".tif") and path.isfile(path.join(src1, i))]
       for f in files:
        shutil.move(path.join(src1, f), dst1)
# Out:
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_10L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_10R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_11L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_11R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_12L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_12R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_13L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_13R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_1L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_1R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_2L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_2R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_3L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_3R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_4L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_4R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_5L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_5R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_6L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_6R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_7L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_7R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_8L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_8R_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_9L_1stHO.png (700, 700, 1050, 1050)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (0, 0, 350, 350)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (0, 350, 350, 700)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (0, 700, 350, 1050)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (350, 0, 700, 350)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (350, 350, 700, 700)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (350, 700, 700, 1050)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (700, 0, 1050, 350)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (700, 350, 1050, 700)
# ChaseDB/training\1st_manual\Image_9R_1stHO.png (700, 700, 1050, 1050)

# %%
PATH1 = 'ChaseDB/training'

# %%
images=glob.glob(os.path.join(PATH1,'output_images','*.TIFF'))
mask=glob.glob(os.path.join(PATH1,'output_1st_manual','*.tif'))

# %%
def get_data(path, resize_dim=128):
    img=cv2.imread(path)
    img_rz=cv2.resize(img,(resize_dim,resize_dim),interpolation=cv2.INTER_AREA)
    return img_rz

# %%
def get_data_gif(path, resize_dim=128):
    img=plt.imread(path)
    img_rz=cv2.resize(img,(resize_dim,resize_dim),interpolation=cv2.INTER_AREA)
    return img_rz

# %%
orig_images=np.array([get_data(path) for path in images])
orig_images.shape
# Out:
# (234, 128, 128, 3)

# %%
plt.imshow(orig_images[1])

# %%
masks=np.array([get_data_gif(path) for path in mask])
masks.shape
# Out:
# (234, 128, 128, 3)

# %%
plt.imshow(masks[1])

# %%
masks.shape, orig_images.shape
# Out:
# ((234, 128, 128, 3), (234, 128, 128, 3))

# %%
orig_images = orig_images / 255
masks = masks / 255

# %%
VGG_Weights_path = "C:/Users/subah/fcn/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
n_classes=3

# %%
def FCN8( nClasses ,  input_height=128, input_width=128):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 512,512,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_4 = Conv2DTranspose( nClasses , kernel_size=(4,4) ,  strides=(4,4) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 512, 512, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
    pool411_2 = (Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING ))(pool411)
    
    pool311 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool3_11", data_format=IMAGE_ORDERING))(pool3)
        
    o = Add(name="add")([pool411_2, pool311, conv7_4 ])
    o = Conv2DTranspose( nClasses , kernel_size=(8,8) ,  strides=(8,8) , use_bias=False, data_format=IMAGE_ORDERING )(o)
    o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

model = FCN8(nClasses     = n_classes,  
             input_height = 128, 
             input_width  = 128)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 128, 128, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 128, 128, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 64, 64, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 64, 64, 128)  147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 32, 32, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 32, 32, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 32, 32, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 32, 32, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 16, 16, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 16, 16, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 16, 16, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 16, 16, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 8, 8, 512)    0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 8, 8, 512)    2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 8, 8, 512)    2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 8, 8, 512)    2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 4, 4, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 4, 4, 4096)   102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# pool4_11 (Conv2D)               (None, 8, 8, 3)      1539        block4_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 4, 4, 4096)   16781312    conv6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 3)    36          pool4_11[0][0]
# __________________________________________________________________________________________________
# pool3_11 (Conv2D)               (None, 16, 16, 3)    771         block3_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 3)    196608      conv7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 3)    0           conv2d_transpose_2[0][0]
#                                                                  pool3_11[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 3)  576         add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 3)  0           conv2d_transpose_3[0][0]
# ==================================================================================================
# Total params: 134,460,074
# Trainable params: 134,460,074
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(orig_images, masks, epochs = 50, batch_size= 16 , shuffle = True, validation_split = 0.1)
# Out:
# WARNING:tensorflow:From C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 210 samples, validate on 24 samples
# Epoch 1/50
# 210/210 [==============================] - 234s 1s/step - loss: 0.4550 - accuracy: 0.8939 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 2/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 3/50
# 210/210 [==============================] - 208s 992ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 4/50
# 210/210 [==============================] - 204s 972ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 5/50
# 210/210 [==============================] - 184s 877ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 6/50
# 210/210 [==============================] - 205s 974ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 7/50
# 210/210 [==============================] - 207s 986ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 8/50
# 210/210 [==============================] - 196s 935ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 9/50
# 210/210 [==============================] - 200s 952ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 10/50
# 210/210 [==============================] - 187s 889ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 11/50
# 210/210 [==============================] - 183s 871ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 12/50
# 210/210 [==============================] - 188s 894ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 13/50
# 210/210 [==============================] - 176s 837ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 14/50
# 210/210 [==============================] - 186s 884ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 15/50
# 210/210 [==============================] - 182s 868ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 16/50
# 210/210 [==============================] - 165s 784ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 17/50
# 210/210 [==============================] - 131s 623ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 18/50
# 210/210 [==============================] - 135s 642ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 19/50
# 210/210 [==============================] - 146s 694ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 20/50
# 210/210 [==============================] - 136s 650ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 21/50
# 210/210 [==============================] - 141s 672ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 22/50
# 210/210 [==============================] - 136s 648ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 23/50
# 210/210 [==============================] - 134s 637ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 24/50
# 210/210 [==============================] - 142s 677ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 25/50
# 210/210 [==============================] - 144s 687ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 26/50
# 210/210 [==============================] - 146s 693ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 27/50
# 210/210 [==============================] - 138s 659ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 28/50
# 210/210 [==============================] - 136s 647ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 29/50
# 210/210 [==============================] - 142s 674ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 30/50
# 210/210 [==============================] - 137s 651ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 31/50
# 210/210 [==============================] - 134s 638ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 32/50
# 210/210 [==============================] - 141s 669ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 33/50
# 210/210 [==============================] - 140s 668ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 34/50
# 210/210 [==============================] - 149s 711ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 35/50
# 210/210 [==============================] - 145s 689ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 36/50
# 210/210 [==============================] - 145s 692ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 37/50
# 210/210 [==============================] - 141s 671ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 38/50
# 210/210 [==============================] - 140s 666ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 39/50
# 210/210 [==============================] - 143s 681ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 40/50
# 210/210 [==============================] - 145s 689ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 41/50
# 210/210 [==============================] - 133s 633ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 42/50
# 210/210 [==============================] - 136s 646ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 43/50
# 210/210 [==============================] - 145s 691ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 44/50
# 210/210 [==============================] - 127s 606ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 45/50
# 210/210 [==============================] - 130s 618ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 46/50
# 210/210 [==============================] - 138s 655ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 47/50
# 210/210 [==============================] - 137s 655ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 48/50
# 210/210 [==============================] - 133s 635ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 49/50
# 210/210 [==============================] - 127s 604ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191
# Epoch 50/50
# 210/210 [==============================] - 130s 621ms/step - loss: 0.4484 - accuracy: 0.9023 - val_loss: 0.4404 - val_accuracy: 0.9191

# %%
PATH2 = 'ChaseDB/test'

# %%
t_images=glob.glob(os.path.join(PATH2,'images','*.jpg'))

# %%
if not os.path.exists('./ChaseDB/test/output_images'):
    os.makedirs('./ChaseDB/test/output_images')
src = "./ChaseDB/test/images/"
dst = "./ChaseDB/test/output_images/"

# %%
cropheight=350
cropwidth = 350
k=-1
for file in t_images:
    k+=1
    im = Image.open(t_images[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (t_images[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (t_images[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# ChaseDB/test\images\Image_14L.jpg (0, 0, 350, 350)
# ChaseDB/test\images\Image_14L.jpg (0, 350, 350, 700)
# ChaseDB/test\images\Image_14L.jpg (0, 700, 350, 1050)
# ChaseDB/test\images\Image_14L.jpg (350, 0, 700, 350)
# ChaseDB/test\images\Image_14L.jpg (350, 350, 700, 700)
# ChaseDB/test\images\Image_14L.jpg (350, 700, 700, 1050)
# ChaseDB/test\images\Image_14L.jpg (700, 0, 1050, 350)
# ChaseDB/test\images\Image_14L.jpg (700, 350, 1050, 700)
# ChaseDB/test\images\Image_14L.jpg (700, 700, 1050, 1050)
# ChaseDB/test\images\Image_14R.jpg (0, 0, 350, 350)
# ChaseDB/test\images\Image_14R.jpg (0, 350, 350, 700)
# ChaseDB/test\images\Image_14R.jpg (0, 700, 350, 1050)
# ChaseDB/test\images\Image_14R.jpg (350, 0, 700, 350)
# ChaseDB/test\images\Image_14R.jpg (350, 350, 700, 700)
# ChaseDB/test\images\Image_14R.jpg (350, 700, 700, 1050)
# ChaseDB/test\images\Image_14R.jpg (700, 0, 1050, 350)
# ChaseDB/test\images\Image_14R.jpg (700, 350, 1050, 700)
# ChaseDB/test\images\Image_14R.jpg (700, 700, 1050, 1050)

# %%
PATH3 = 'ChaseDB/test'

# %%
t_images=glob.glob(os.path.join(PATH3,'output_images','*.tiff'))

# %%
test_images=np.array([get_data(path) for path in t_images])
test_images.shape
# Out:
# (18, 128, 128, 3)

# %%
plt.imshow(test_images[0])

# %%
test_images.shape
# Out:
# (18, 128, 128, 3)

# %%
test_images = test_images / 255

# %%
imgs_mask_test = model.predict(test_images, verbose=1)
# Out:
# 18/18 [==============================] - 1s 55ms/step

# %%
idx = random.randint(0, len(imgs_mask_test))
i = imgs_mask_test[idx]
i = i[:, :, 0]
i.shape
# Out:
# (128, 128)

# %%
plt.imshow(imgs_mask_test[1], cmap='gray')

# %%
plt.imshow(i, cmap='gray')

# %%
yp = np.round(imgs_mask_test,0)

# %%
idx = random.randint(0, len(yp))
i = imgs_mask_test[idx]
i = i[:, :, 0]
i.shape
# Out:
# (128, 128)

# %%
plt.imshow(i, cmap='gray')
