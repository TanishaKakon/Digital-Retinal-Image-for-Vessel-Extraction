# %%
import numpy as np 
import pandas as pd 
import os
import glob
import cv2
import random
import sys
import shutil
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import cm
from os import path
from PIL import Image
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import optimizers
from keras.utils import to_categorical, plot_model
from keras.layers import Dense, Input, Conv2D, Flatten, MaxPooling2D, Activation
from keras.models import Model, Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam, SGD, RMSprop
from keras.applications.vgg16 import VGG16
from keras.models import load_model
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\subah\anaconda3\envs\py36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
PATH_DRIVE = './All_3/DRIVE/training'

# %%
mask_DRIVE=glob.glob(os.path.join(PATH_DRIVE,'1st_manual','*.jpg'))

# %%
i=21
for file in mask_DRIVE:
    img = cv2.imread('C:/Users/subah/fcn/ALL_3/DRIVE/training/1st_manual/'+str(i)+'_manual1.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ALL_3/DRIVE/training/1st_manual/'+str(i)+'_manual1.jpg', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape

# %%
images_DRIVE=glob.glob(os.path.join(PATH_DRIVE,'images','*.TIF'))
mask_DRIVE=glob.glob(os.path.join(PATH_DRIVE,'1st_manual','*.jpg'))
if not os.path.exists('./All_3/training/output_images'):
    os.makedirs('./All_3/training/output_images')
if not os.path.exists('./All_3/training/output_1st_manual'):
    os.makedirs('./All_3/training/output_1st_manual')
src = "./All_3/DRIVE/training/images/"
dst = "./All_3/training/output_images/"
src1= "./All_3/DRIVE/training/1st_manual/"
dst1 = "./All_3/training/output_1st_manual/"

# %%
cropheight=200
cropwidth = 200
k=-1
for file in images_DRIVE:
    k+=1
    im = Image.open(images_DRIVE[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (images_DRIVE[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (images_DRIVE[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# ./All_3/DRIVE/training\images\21_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\21_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\21_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\21_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\21_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\21_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\21_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\21_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\21_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\22_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\22_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\22_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\22_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\22_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\22_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\22_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\22_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\22_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\23_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\23_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\23_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\23_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\23_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\23_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\23_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\23_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\23_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\24_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\24_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\24_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\24_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\24_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\24_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\24_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\24_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\24_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\25_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\25_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\25_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\25_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\25_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\25_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\25_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\25_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\25_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\26_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\26_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\26_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\26_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\26_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\26_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\26_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\26_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\26_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\27_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\27_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\27_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\27_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\27_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\27_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\27_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\27_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\27_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\28_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\28_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\28_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\28_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\28_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\28_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\28_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\28_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\28_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\29_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\29_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\29_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\29_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\29_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\29_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\29_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\29_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\29_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\30_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\30_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\30_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\30_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\30_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\30_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\30_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\30_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\30_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\31_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\31_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\31_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\31_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\31_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\31_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\31_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\31_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\31_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\32_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\32_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\32_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\32_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\32_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\32_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\32_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\32_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\32_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\33_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\33_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\33_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\33_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\33_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\33_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\33_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\33_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\33_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\34_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\34_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\34_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\34_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\34_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\34_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\34_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\34_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\34_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\35_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\35_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\35_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\35_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\35_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\35_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\35_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\35_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\35_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\36_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\36_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\36_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\36_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\36_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\36_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\36_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\36_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\36_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\37_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\37_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\37_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\37_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\37_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\37_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\37_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\37_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\37_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\38_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\38_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\38_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\38_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\38_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\38_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\38_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\38_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\38_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\39_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\39_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\39_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\39_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\39_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\39_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\39_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\39_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\39_training.tif (400, 400, 600, 600)
# ./All_3/DRIVE/training\images\40_training.tif (0, 0, 200, 200)
# ./All_3/DRIVE/training\images\40_training.tif (0, 200, 200, 400)
# ./All_3/DRIVE/training\images\40_training.tif (0, 400, 200, 600)
# ./All_3/DRIVE/training\images\40_training.tif (200, 0, 400, 200)
# ./All_3/DRIVE/training\images\40_training.tif (200, 200, 400, 400)
# ./All_3/DRIVE/training\images\40_training.tif (200, 400, 400, 600)
# ./All_3/DRIVE/training\images\40_training.tif (400, 0, 600, 200)
# ./All_3/DRIVE/training\images\40_training.tif (400, 200, 600, 400)
# ./All_3/DRIVE/training\images\40_training.tif (400, 400, 600, 600)

# %%
cropheight=200
cropwidth = 200
k=-1
for file in mask_DRIVE:
    k+=1
    im = Image.open(mask_DRIVE[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (mask_DRIVE[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tif' % (mask_DRIVE[k], i, j))
       files = [i for i in os.listdir(src1) if i.endswith(".tif") and path.isfile(path.join(src1, i))]
       for f in files:
        shutil.move(path.join(src1, f), dst1)
# Out:
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\21_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\22_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\23_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\24_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\25_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\26_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\27_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\28_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\29_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\30_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\31_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\32_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\33_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\34_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\35_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\36_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\37_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\38_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\39_manual1.gif (400, 400, 600, 600)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (0, 0, 200, 200)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (0, 200, 200, 400)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (0, 400, 200, 600)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (200, 0, 400, 200)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (200, 200, 400, 400)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (200, 400, 400, 600)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (400, 0, 600, 200)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (400, 200, 600, 400)
# ./All_3/DRIVE/training\1st_manual\40_manual1.gif (400, 400, 600, 600)

# %%
PATH_Stare = './All_4/Stare/training'

# %%
images_Stare=glob.glob(os.path.join(PATH_Stare,'images','*.TIF'))
mask_Stare=glob.glob(os.path.join(PATH_Stare,'1st_manual','*.GIF'))
src = "./All_4/Stare/training/images/"
dst = "./All_4/training/output_images/"
src1= "./All_4/Stare/training/1st_manual/"
dst1 = "./All_4/training/output_1st_manual/"

# %%
cropheight=350
cropwidth = 350
k=-1
for file in images_Stare:
    k+=1
    im = Image.open(images_Stare[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (images_Stare[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (images_Stare[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)

# %%
cropheight=350
cropwidth = 350
k=-1
for file in mask_Stare:
    k+=1
    im = Image.open(mask_Stare[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (mask_Stare[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tif' % (mask_Stare[k], i, j))
       files = [i for i in os.listdir(src1) if i.endswith(".tif") and path.isfile(path.join(src1, i))]
       for f in files:
        shutil.move(path.join(src1, f), dst1)

# %%
PATH_ChaseDB = './ALL_3/ChaseDB/training/manual'
mask_ChaseDB=glob.glob(os.path.join(PATH_ChaseDB,'L','*.png'))

# %%
i=1
for file in mask_ChaseDB:
    img = cv2.imread('C:/Users/subah/fcn/ALL_3/ChaseDB/training/manual/L/Image_'+str(i)+'L_1stHO.png')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ALL_3/ChaseDB/training/1st_manual/Image_'+str(i)+'L_1stHO.png', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape

# %%
PATH_ChaseDB = './ALL_3/ChaseDB/training/manual'
mask_ChaseDB=glob.glob(os.path.join(PATH_ChaseDB,'R','*.png'))

# %%
i=1
for file in mask_ChaseDB:
    img = cv2.imread('C:/Users/subah/fcn/ALL_3/ChaseDB/training/manual/R/Image_'+str(i)+'R_1stHO.png')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ALL_3/ChaseDB/training/1st_manual/Image_'+str(i)+'R_1stHO.png', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape

# %%
PATH_ChaseDB = './All_3/ChaseDB/training'

# %%
images_ChaseDB=glob.glob(os.path.join(PATH_ChaseDB,'images','*.jpg'))
mask_ChaseDB=glob.glob(os.path.join(PATH_ChaseDB,'1st_manual','*.png'))
src = "./All_3/ChaseDB/training/images/"
dst = "./All_3/training/output_images/"
src1= "./All_3/ChaseDB/training/1st_manual/"
dst1 = "./All_3/training/output_1st_manual/"

# %%
cropheight=350
cropwidth = 350
k=-1
for file in images_ChaseDB:
    k+=1
    im = Image.open(images_ChaseDB[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (images_ChaseDB[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (images_ChaseDB[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# ./All_3/ChaseDB/training\images\Image_01L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_01L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_01R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_02L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_02R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_03L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_03R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_04L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_04R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_05L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_05R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_06L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_06R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_07L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_07R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_08L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_08R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_09L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_09R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_10L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_10R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_11L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_11R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_12L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_12R.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_13L.jpg (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (0, 0, 350, 350)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (0, 350, 350, 700)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (350, 0, 700, 350)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (350, 350, 700, 700)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\images\Image_13R.jpg (700, 700, 1050, 1050)

# %%
cropheight=350
cropwidth = 350
k=-1
for file in mask_ChaseDB:
    k+=1
    im = Image.open(mask_ChaseDB[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (mask_ChaseDB[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tif' % (mask_ChaseDB[k], i, j))
       files = [i for i in os.listdir(src1) if i.endswith(".tif") and path.isfile(path.join(src1, i))]
       for f in files:
        shutil.move(path.join(src1, f), dst1)
# Out:
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_01L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_01R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_02L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_02R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_03L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_03R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_04L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_04R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_05L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_05R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_06L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_06R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_07L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_07R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_08L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_08R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_09L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_09R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_10L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_10R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_11L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_11R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_12L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_12R_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_13L_1stHO.png (700, 700, 1050, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (0, 0, 350, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (0, 350, 350, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (0, 700, 350, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (350, 0, 700, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (350, 350, 700, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (350, 700, 700, 1050)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (700, 0, 1050, 350)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (700, 350, 1050, 700)
# ./All_3/ChaseDB/training\1st_manual\Image_13R_1stHO.png (700, 700, 1050, 1050)

# %%
PATH_HRF = './ALL_3/HRF/training/manual'
mask_HRF=glob.glob(os.path.join(PATH_HRF,'dr','*.jpg'))

# %%
i=1
for file in mask_HRF:
    img = cv2.imread('C:/Users/subah/fcn/ALL_3/HRF/training/manual/dr/'+str(i)+'_dr.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ALL_3/HRF/training/1st_manual/'+str(i)+'_dr.jpg', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape

# %%
PATH_HRF = './ALL_3/HRF/training/manual'
mask_HRF=glob.glob(os.path.join(PATH_HRF,'g','*.jpg'))

# %%
i=1
for file in mask_HRF:
    img = cv2.imread('C:/Users/subah/fcn/ALL_3/HRF/training/manual/g/'+str(i)+'_g.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ALL_3/HRF/training/1st_manual/'+str(i)+'_g.jpg', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape

# %%
PATH_HRF = './ALL_3/HRF/training/manual'
mask_HRF=glob.glob(os.path.join(PATH_HRF,'h','*.jpg'))

# %%
i=1
for file in mask_HRF:
    img = cv2.imread('C:/Users/subah/fcn/ALL_3/HRF/training/manual/h/'+str(i)+'_h.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = np.zeros_like(img)
    img2[:,:,0] = gray
    img2[:,:,1] = gray
    img2[:,:,2] = gray
    cv2.imwrite('C:/Users/subah/fcn/ALL_3/HRF/training/1st_manual/'+str(i)+'_h.jpg', img2)
    i+=1

# %%
plt.imshow(img2)

# %%
img2.shape

# %%
PATH_HRF = './All_3/HRF/training'

# %%
images_HRF=glob.glob(os.path.join(PATH_HRF,'images','*.jpg'))
mask_HRF=glob.glob(os.path.join(PATH_HRF,'1st_manual','*.jpg'))
src = "./All_3/HRF/training/images/"
dst = "./All_3/training/output_images/"
src1= "./All_3/HRF/training/1st_manual/"
dst1 = "./All_3/training/output_1st_manual/"

# %%
cropheight=900
cropwidth = 600
k=-1
for file in images_HRF:
    k+=1
    im = Image.open(images_HRF[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (images_HRF[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (images_HRF[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# ./All_3/HRF/training\images\01_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\01_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\01_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\01_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\01_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\01_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\01_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\01_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\01_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\01_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\01_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\01_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\01_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\01_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\01_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\01_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\01_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\01_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\01_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\01_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\01_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\01_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\01_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\01_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\01_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\01_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\01_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\01_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\01_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\01_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\01_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\01_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\01_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\01_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\01_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\01_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\01_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\01_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\01_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\01_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\01_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\01_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\01_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\01_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\01_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\01_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\01_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\01_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\01_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\01_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\01_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\01_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\01_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\01_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\02_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\02_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\02_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\02_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\02_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\02_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\02_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\02_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\02_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\02_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\02_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\02_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\02_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\02_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\02_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\02_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\02_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\02_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\02_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\02_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\02_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\02_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\02_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\02_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\02_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\02_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\02_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\02_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\02_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\02_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\02_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\02_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\02_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\02_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\02_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\02_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\02_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\02_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\02_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\02_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\02_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\02_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\02_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\02_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\02_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\02_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\02_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\02_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\02_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\02_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\02_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\02_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\02_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\02_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\03_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\03_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\03_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\03_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\03_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\03_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\03_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\03_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\03_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\03_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\03_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\03_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\03_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\03_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\03_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\03_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\03_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\03_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\03_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\03_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\03_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\03_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\03_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\03_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\03_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\03_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\03_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\03_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\03_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\03_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\03_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\03_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\03_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\03_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\03_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\03_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\03_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\03_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\03_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\03_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\03_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\03_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\03_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\03_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\03_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\03_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\03_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\03_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\03_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\03_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\03_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\03_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\03_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\03_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\04_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\04_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\04_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\04_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\04_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\04_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\04_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\04_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\04_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\04_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\04_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\04_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\04_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\04_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\04_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\04_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\04_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\04_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\04_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\04_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\04_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\04_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\04_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\04_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\04_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\04_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\04_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\04_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\04_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\04_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\04_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\04_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\04_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\04_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\04_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\04_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\04_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\04_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\04_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\04_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\04_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\04_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\04_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\04_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\04_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\04_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\04_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\04_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\04_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\04_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\04_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\04_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\04_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\04_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\05_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\05_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\05_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\05_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\05_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\05_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\05_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\05_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\05_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\05_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\05_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\05_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\05_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\05_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\05_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\05_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\05_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\05_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\05_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\05_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\05_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\05_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\05_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\05_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\05_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\05_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\05_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\05_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\05_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\05_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\05_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\05_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\05_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\05_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\05_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\05_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\05_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\05_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\05_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\05_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\05_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\05_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\05_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\05_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\05_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\05_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\05_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\05_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\05_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\05_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\05_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\05_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\05_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\05_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\06_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\06_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\06_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\06_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\06_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\06_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\06_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\06_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\06_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\06_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\06_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\06_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\06_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\06_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\06_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\06_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\06_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\06_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\06_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\06_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\06_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\06_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\06_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\06_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\06_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\06_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\06_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\06_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\06_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\06_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\06_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\06_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\06_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\06_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\06_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\06_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\06_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\06_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\06_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\06_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\06_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\06_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\06_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\06_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\06_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\06_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\06_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\06_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\06_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\06_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\06_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\06_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\06_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\06_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\07_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\07_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\07_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\07_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\07_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\07_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\07_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\07_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\07_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\07_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\07_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\07_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\07_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\07_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\07_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\07_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\07_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\07_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\07_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\07_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\07_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\07_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\07_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\07_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\07_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\07_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\07_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\07_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\07_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\07_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\07_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\07_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\07_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\07_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\07_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\07_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\07_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\07_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\07_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\07_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\07_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\07_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\07_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\07_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\07_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\07_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\07_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\07_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\07_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\07_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\07_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\07_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\07_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\07_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\08_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\08_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\08_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\08_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\08_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\08_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\08_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\08_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\08_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\08_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\08_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\08_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\08_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\08_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\08_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\08_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\08_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\08_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\08_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\08_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\08_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\08_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\08_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\08_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\08_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\08_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\08_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\08_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\08_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\08_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\08_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\08_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\08_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\08_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\08_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\08_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\08_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\08_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\08_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\08_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\08_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\08_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\08_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\08_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\08_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\08_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\08_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\08_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\08_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\08_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\08_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\08_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\08_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\08_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\09_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\09_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\09_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\09_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\09_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\09_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\09_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\09_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\09_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\09_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\09_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\09_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\09_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\09_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\09_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\09_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\09_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\09_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\09_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\09_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\09_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\09_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\09_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\09_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\09_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\09_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\09_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\09_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\09_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\09_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\09_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\09_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\09_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\09_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\09_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\09_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\09_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\09_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\09_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\09_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\09_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\09_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\09_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\09_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\09_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\09_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\09_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\09_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\09_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\09_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\09_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\09_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\09_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\09_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\10_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\10_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\10_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\10_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\10_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\10_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\10_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\10_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\10_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\10_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\10_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\10_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\10_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\10_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\10_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\10_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\10_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\10_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\10_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\10_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\10_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\10_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\10_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\10_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\10_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\10_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\10_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\10_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\10_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\10_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\10_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\10_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\10_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\10_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\10_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\10_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\10_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\10_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\10_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\10_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\10_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\10_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\10_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\10_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\10_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\10_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\10_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\10_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\10_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\10_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\10_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\10_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\10_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\10_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\11_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\11_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\11_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\11_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\11_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\11_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\11_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\11_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\11_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\11_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\11_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\11_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\11_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\11_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\11_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\11_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\11_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\11_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\11_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\11_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\11_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\11_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\11_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\11_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\11_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\11_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\11_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\11_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\11_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\11_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\11_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\11_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\11_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\11_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\11_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\11_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\11_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\11_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\11_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\11_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\11_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\11_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\11_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\11_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\11_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\11_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\11_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\11_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\11_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\11_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\11_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\11_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\11_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\11_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\12_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\12_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\12_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\12_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\12_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\12_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\12_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\12_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\12_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\12_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\12_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\12_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\12_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\12_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\12_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\12_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\12_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\12_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\12_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\12_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\12_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\12_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\12_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\12_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\12_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\12_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\12_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\12_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\12_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\12_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\12_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\12_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\12_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\12_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\12_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\12_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\12_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\12_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\12_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\12_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\12_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\12_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\12_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\12_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\12_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\12_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\12_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\12_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\12_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\12_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\12_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\12_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\12_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\12_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\13_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\13_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\13_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\13_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\13_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\13_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\13_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\13_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\13_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\13_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\13_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\13_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\13_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\13_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\13_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\13_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\13_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\13_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\13_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\13_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\13_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\13_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\13_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\13_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\13_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\13_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\13_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\13_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\13_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\13_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\13_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\13_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\13_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\13_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\13_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\13_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\13_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\13_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\13_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\13_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\13_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\13_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\13_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\13_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\13_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\13_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\13_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\13_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\13_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\13_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\13_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\13_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\13_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\13_h.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\14_dr.JPG (0, 0, 600, 900)
# ./All_3/HRF/training\images\14_dr.JPG (0, 900, 600, 1800)
# ./All_3/HRF/training\images\14_dr.JPG (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\14_dr.JPG (600, 0, 1200, 900)
# ./All_3/HRF/training\images\14_dr.JPG (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\14_dr.JPG (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\14_dr.JPG (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\14_dr.JPG (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\14_dr.JPG (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\14_dr.JPG (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\14_dr.JPG (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\14_dr.JPG (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\14_dr.JPG (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\14_dr.JPG (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\14_dr.JPG (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\14_dr.JPG (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\14_dr.JPG (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\14_dr.JPG (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\14_g.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\14_g.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\14_g.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\14_g.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\14_g.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\14_g.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\14_g.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\14_g.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\14_g.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\14_g.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\14_g.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\14_g.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\14_g.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\14_g.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\14_g.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\14_g.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\14_g.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\14_g.jpg (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\images\14_h.jpg (0, 0, 600, 900)
# ./All_3/HRF/training\images\14_h.jpg (0, 900, 600, 1800)
# ./All_3/HRF/training\images\14_h.jpg (0, 1800, 600, 2700)
# ./All_3/HRF/training\images\14_h.jpg (600, 0, 1200, 900)
# ./All_3/HRF/training\images\14_h.jpg (600, 900, 1200, 1800)
# ./All_3/HRF/training\images\14_h.jpg (600, 1800, 1200, 2700)
# ./All_3/HRF/training\images\14_h.jpg (1200, 0, 1800, 900)
# ./All_3/HRF/training\images\14_h.jpg (1200, 900, 1800, 1800)
# ./All_3/HRF/training\images\14_h.jpg (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\images\14_h.jpg (1800, 0, 2400, 900)
# ./All_3/HRF/training\images\14_h.jpg (1800, 900, 2400, 1800)
# ./All_3/HRF/training\images\14_h.jpg (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\images\14_h.jpg (2400, 0, 3000, 900)
# ./All_3/HRF/training\images\14_h.jpg (2400, 900, 3000, 1800)
# ./All_3/HRF/training\images\14_h.jpg (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\images\14_h.jpg (3000, 0, 3600, 900)
# ./All_3/HRF/training\images\14_h.jpg (3000, 900, 3600, 1800)
# ./All_3/HRF/training\images\14_h.jpg (3000, 1800, 3600, 2700)

# %%
cropheight=900
cropwidth = 600
k=-1
for file in mask_HRF:
    k+=1
    im = Image.open(mask_HRF[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (mask_HRF[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tif' % (mask_HRF[k], i, j))
       files = [i for i in os.listdir(src1) if i.endswith(".tif") and path.isfile(path.join(src1, i))]
       for f in files:
        shutil.move(path.join(src1, f), dst1)
# Out:
# ./All_3/HRF/training\1st_manual\01_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\01_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\01_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\01_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\01_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\01_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\01_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\01_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\01_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\01_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\01_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\01_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\01_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\01_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\01_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\01_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\01_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\01_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\01_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\01_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\01_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\01_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\01_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\01_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\01_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\01_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\01_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\01_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\01_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\01_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\01_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\01_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\01_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\01_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\01_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\01_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\01_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\01_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\01_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\01_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\01_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\01_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\01_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\01_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\01_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\01_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\01_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\01_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\01_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\01_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\01_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\01_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\01_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\01_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\02_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\02_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\02_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\02_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\02_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\02_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\02_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\02_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\02_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\02_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\02_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\02_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\02_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\02_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\02_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\02_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\02_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\02_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\02_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\02_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\02_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\02_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\02_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\02_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\02_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\02_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\02_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\02_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\02_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\02_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\02_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\02_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\02_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\02_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\02_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\02_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\02_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\02_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\02_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\02_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\02_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\02_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\02_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\02_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\02_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\02_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\02_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\02_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\02_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\02_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\02_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\02_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\02_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\02_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\03_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\03_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\03_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\03_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\03_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\03_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\03_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\03_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\03_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\03_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\03_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\03_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\03_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\03_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\03_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\03_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\03_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\03_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\03_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\03_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\03_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\03_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\03_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\03_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\03_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\03_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\03_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\03_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\03_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\03_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\03_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\03_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\03_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\03_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\03_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\03_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\03_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\03_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\03_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\03_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\03_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\03_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\03_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\03_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\03_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\03_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\03_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\03_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\03_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\03_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\03_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\03_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\03_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\03_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\04_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\04_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\04_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\04_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\04_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\04_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\04_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\04_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\04_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\04_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\04_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\04_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\04_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\04_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\04_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\04_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\04_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\04_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\04_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\04_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\04_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\04_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\04_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\04_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\04_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\04_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\04_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\04_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\04_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\04_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\04_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\04_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\04_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\04_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\04_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\04_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\04_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\04_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\04_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\04_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\04_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\04_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\04_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\04_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\04_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\04_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\04_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\04_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\04_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\04_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\04_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\04_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\04_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\04_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\05_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\05_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\05_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\05_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\05_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\05_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\05_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\05_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\05_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\05_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\05_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\05_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\05_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\05_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\05_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\05_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\05_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\05_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\05_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\05_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\05_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\05_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\05_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\05_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\05_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\05_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\05_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\05_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\05_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\05_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\05_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\05_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\05_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\05_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\05_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\05_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\05_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\05_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\05_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\05_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\05_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\05_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\05_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\05_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\05_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\05_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\05_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\05_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\05_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\05_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\05_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\05_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\05_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\05_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\06_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\06_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\06_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\06_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\06_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\06_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\06_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\06_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\06_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\06_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\06_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\06_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\06_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\06_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\06_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\06_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\06_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\06_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\06_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\06_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\06_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\06_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\06_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\06_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\06_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\06_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\06_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\06_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\06_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\06_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\06_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\06_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\06_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\06_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\06_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\06_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\06_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\06_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\06_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\06_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\06_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\06_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\06_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\06_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\06_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\06_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\06_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\06_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\06_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\06_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\06_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\06_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\06_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\06_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\07_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\07_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\07_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\07_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\07_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\07_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\07_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\07_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\07_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\07_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\07_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\07_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\07_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\07_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\07_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\07_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\07_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\07_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\07_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\07_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\07_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\07_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\07_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\07_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\07_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\07_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\07_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\07_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\07_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\07_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\07_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\07_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\07_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\07_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\07_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\07_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\07_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\07_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\07_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\07_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\07_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\07_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\07_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\07_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\07_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\07_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\07_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\07_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\07_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\07_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\07_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\07_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\07_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\07_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\08_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\08_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\08_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\08_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\08_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\08_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\08_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\08_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\08_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\08_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\08_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\08_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\08_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\08_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\08_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\08_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\08_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\08_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\08_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\08_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\08_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\08_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\08_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\08_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\08_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\08_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\08_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\08_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\08_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\08_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\08_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\08_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\08_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\08_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\08_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\08_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\08_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\08_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\08_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\08_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\08_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\08_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\08_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\08_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\08_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\08_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\08_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\08_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\08_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\08_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\08_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\08_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\08_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\08_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\09_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\09_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\09_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\09_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\09_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\09_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\09_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\09_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\09_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\09_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\09_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\09_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\09_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\09_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\09_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\09_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\09_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\09_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\09_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\09_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\09_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\09_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\09_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\09_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\09_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\09_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\09_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\09_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\09_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\09_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\09_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\09_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\09_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\09_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\09_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\09_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\09_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\09_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\09_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\09_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\09_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\09_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\09_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\09_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\09_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\09_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\09_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\09_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\09_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\09_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\09_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\09_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\09_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\09_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\10_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\10_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\10_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\10_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\10_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\10_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\10_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\10_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\10_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\10_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\10_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\10_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\10_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\10_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\10_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\10_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\10_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\10_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\10_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\10_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\10_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\10_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\10_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\10_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\10_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\10_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\10_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\10_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\10_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\10_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\10_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\10_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\10_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\10_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\10_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\10_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\10_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\10_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\10_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\10_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\10_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\10_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\10_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\10_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\10_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\10_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\10_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\10_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\10_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\10_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\10_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\10_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\10_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\10_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\11_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\11_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\11_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\11_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\11_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\11_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\11_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\11_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\11_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\11_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\11_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\11_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\11_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\11_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\11_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\11_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\11_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\11_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\11_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\11_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\11_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\11_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\11_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\11_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\11_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\11_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\11_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\11_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\11_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\11_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\11_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\11_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\11_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\11_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\11_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\11_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\11_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\11_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\11_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\11_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\11_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\11_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\11_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\11_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\11_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\11_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\11_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\11_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\11_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\11_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\11_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\11_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\11_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\11_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\12_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\12_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\12_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\12_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\12_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\12_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\12_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\12_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\12_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\12_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\12_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\12_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\12_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\12_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\12_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\12_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\12_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\12_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\12_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\12_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\12_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\12_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\12_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\12_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\12_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\12_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\12_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\12_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\12_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\12_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\12_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\12_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\12_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\12_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\12_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\12_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\12_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\12_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\12_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\12_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\12_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\12_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\12_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\12_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\12_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\12_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\12_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\12_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\12_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\12_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\12_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\12_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\12_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\12_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\13_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\13_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\13_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\13_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\13_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\13_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\13_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\13_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\13_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\13_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\13_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\13_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\13_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\13_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\13_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\13_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\13_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\13_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\13_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\13_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\13_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\13_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\13_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\13_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\13_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\13_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\13_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\13_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\13_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\13_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\13_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\13_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\13_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\13_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\13_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\13_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\13_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\13_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\13_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\13_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\13_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\13_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\13_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\13_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\13_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\13_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\13_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\13_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\13_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\13_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\13_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\13_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\13_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\13_h.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\14_dr.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\14_dr.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\14_dr.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\14_dr.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\14_dr.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\14_dr.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\14_dr.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\14_dr.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\14_dr.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\14_dr.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\14_dr.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\14_dr.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\14_dr.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\14_dr.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\14_dr.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\14_dr.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\14_dr.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\14_dr.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\14_g.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\14_g.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\14_g.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\14_g.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\14_g.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\14_g.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\14_g.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\14_g.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\14_g.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\14_g.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\14_g.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\14_g.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\14_g.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\14_g.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\14_g.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\14_g.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\14_g.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\14_g.tif (3000, 1800, 3600, 2700)
# ./All_3/HRF/training\1st_manual\14_h.tif (0, 0, 600, 900)
# ./All_3/HRF/training\1st_manual\14_h.tif (0, 900, 600, 1800)
# ./All_3/HRF/training\1st_manual\14_h.tif (0, 1800, 600, 2700)
# ./All_3/HRF/training\1st_manual\14_h.tif (600, 0, 1200, 900)
# ./All_3/HRF/training\1st_manual\14_h.tif (600, 900, 1200, 1800)
# ./All_3/HRF/training\1st_manual\14_h.tif (600, 1800, 1200, 2700)
# ./All_3/HRF/training\1st_manual\14_h.tif (1200, 0, 1800, 900)
# ./All_3/HRF/training\1st_manual\14_h.tif (1200, 900, 1800, 1800)
# ./All_3/HRF/training\1st_manual\14_h.tif (1200, 1800, 1800, 2700)
# ./All_3/HRF/training\1st_manual\14_h.tif (1800, 0, 2400, 900)
# ./All_3/HRF/training\1st_manual\14_h.tif (1800, 900, 2400, 1800)
# ./All_3/HRF/training\1st_manual\14_h.tif (1800, 1800, 2400, 2700)
# ./All_3/HRF/training\1st_manual\14_h.tif (2400, 0, 3000, 900)
# ./All_3/HRF/training\1st_manual\14_h.tif (2400, 900, 3000, 1800)
# ./All_3/HRF/training\1st_manual\14_h.tif (2400, 1800, 3000, 2700)
# ./All_3/HRF/training\1st_manual\14_h.tif (3000, 0, 3600, 900)
# ./All_3/HRF/training\1st_manual\14_h.tif (3000, 900, 3600, 1800)
# ./All_3/HRF/training\1st_manual\14_h.tif (3000, 1800, 3600, 2700)

# %%
PATH1 = 'All_3//training'

# %%
images=glob.glob(os.path.join(PATH1,'output_images','*.tiff'))
mask=glob.glob(os.path.join(PATH1,'output_1st_manual','*.tif'))

# %%
def get_data(path, resize_dim=128):
    img=cv2.imread(path)
    img_rz=cv2.resize(img,(resize_dim,resize_dim),interpolation=cv2.INTER_AREA)
    return img_rz

# %%
def get_data_gif(path, resize_dim=128):
    img=plt.imread(path)
    img_rz=cv2.resize(img,(resize_dim,resize_dim),interpolation=cv2.INTER_AREA)
    return img_rz

# %%
orig_images=np.array([get_data(path) for path in images])
orig_images.shape
# Out:
# (1170, 128, 128)

# %%
plt.imshow(orig_images[0])

# %%
masks=np.array([get_data_gif(path) for path in mask])
masks.shape
# Out:
# (1170, 128, 128)

# %%
plt.imshow(masks[0])

# %%
masks.shape, orig_images.shape
# Out:
# ((1170, 128, 128, 1), (1170, 128, 128, 1))

# %%
orig_images = orig_images / 255
masks = masks / 255

# %%
VGG_Weights_path = "C:/Users/subah/fcn/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
n_classes=3

# %%
def FCN8( nClasses ,  input_height=128, input_width=128):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 512,512,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_4 = Conv2DTranspose( nClasses , kernel_size=(4,4) ,  strides=(4,4) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 512, 512, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
    pool411_2 = (Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING ))(pool411)
    
    pool311 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool3_11", data_format=IMAGE_ORDERING))(pool3)
        
    o = Add(name="add")([pool411_2, pool311, conv7_4 ])
    o = Conv2DTranspose( nClasses , kernel_size=(8,8) ,  strides=(8,8) , use_bias=False, data_format=IMAGE_ORDERING )(o)
    o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

model = FCN8(nClasses     = n_classes,  
             input_height = 128, 
             input_width  = 128)
model.summary()

# %%
model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(orig_images, masks, epochs = 50, batch_size= 16 , shuffle = True, validation_split = 0.1)

# %%
PATH_DRIVE= 'All_3//DRIVE//test'

# %%
t_images_DRIVE=glob.glob(os.path.join(PATH_DRIVE,'images','*.TIF'))

# %%
if not os.path.exists('.All_3/test/output_images'):
    os.makedirs('./All_3/test/output_images')
src = "./All_3/DRIVE/test/images/"
dst = "./All_3/test/output_images/"

# %%
cropheight=200
cropwidth = 200
k=-1
for file in t_images_DRIVE:
    k+=1
    im = Image.open(t_images_DRIVE[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (t_images_DRIVE[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (t_images_DRIVE[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# All_3//DRIVE//test\images\01_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\01_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\01_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\01_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\01_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\01_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\01_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\01_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\01_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\02_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\02_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\02_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\02_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\02_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\02_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\02_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\02_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\02_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\03_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\03_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\03_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\03_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\03_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\03_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\03_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\03_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\03_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\04_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\04_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\04_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\04_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\04_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\04_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\04_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\04_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\04_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\05_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\05_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\05_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\05_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\05_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\05_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\05_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\05_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\05_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\06_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\06_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\06_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\06_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\06_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\06_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\06_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\06_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\06_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\07_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\07_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\07_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\07_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\07_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\07_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\07_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\07_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\07_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\08_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\08_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\08_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\08_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\08_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\08_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\08_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\08_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\08_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\09_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\09_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\09_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\09_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\09_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\09_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\09_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\09_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\09_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\10_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\10_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\10_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\10_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\10_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\10_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\10_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\10_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\10_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\11_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\11_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\11_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\11_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\11_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\11_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\11_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\11_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\11_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\12_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\12_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\12_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\12_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\12_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\12_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\12_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\12_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\12_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\13_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\13_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\13_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\13_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\13_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\13_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\13_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\13_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\13_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\14_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\14_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\14_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\14_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\14_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\14_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\14_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\14_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\14_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\15_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\15_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\15_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\15_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\15_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\15_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\15_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\15_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\15_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\16_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\16_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\16_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\16_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\16_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\16_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\16_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\16_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\16_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\17_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\17_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\17_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\17_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\17_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\17_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\17_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\17_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\17_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\18_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\18_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\18_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\18_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\18_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\18_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\18_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\18_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\18_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\19_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\19_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\19_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\19_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\19_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\19_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\19_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\19_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\19_test.tif (400, 400, 600, 600)
# All_3//DRIVE//test\images\20_test.tif (0, 0, 200, 200)
# All_3//DRIVE//test\images\20_test.tif (0, 200, 200, 400)
# All_3//DRIVE//test\images\20_test.tif (0, 400, 200, 600)
# All_3//DRIVE//test\images\20_test.tif (200, 0, 400, 200)
# All_3//DRIVE//test\images\20_test.tif (200, 200, 400, 400)
# All_3//DRIVE//test\images\20_test.tif (200, 400, 400, 600)
# All_3//DRIVE//test\images\20_test.tif (400, 0, 600, 200)
# All_3//DRIVE//test\images\20_test.tif (400, 200, 600, 400)
# All_3//DRIVE//test\images\20_test.tif (400, 400, 600, 600)

# %%
PATH_ChaseDB= 'All_3//ChaseDB//test'

# %%
t_images_ChaseDB=glob.glob(os.path.join(PATH_ChaseDB,'images','*.JPG'))

# %%
src = "./All_3/ChaseDB/test/images/"
dst = "./All_3/test/output_images/"

# %%
cropheight=350
cropwidth = 350
k=-1
for file in t_images_ChaseDB:
    k+=1
    im = Image.open(t_images_ChaseDB[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (t_images_ChaseDB[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (t_images_ChaseDB[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# All_3//ChaseDB//test\images\Image_14L.jpg (0, 0, 350, 350)
# All_3//ChaseDB//test\images\Image_14L.jpg (0, 350, 350, 700)
# All_3//ChaseDB//test\images\Image_14L.jpg (0, 700, 350, 1050)
# All_3//ChaseDB//test\images\Image_14L.jpg (350, 0, 700, 350)
# All_3//ChaseDB//test\images\Image_14L.jpg (350, 350, 700, 700)
# All_3//ChaseDB//test\images\Image_14L.jpg (350, 700, 700, 1050)
# All_3//ChaseDB//test\images\Image_14L.jpg (700, 0, 1050, 350)
# All_3//ChaseDB//test\images\Image_14L.jpg (700, 350, 1050, 700)
# All_3//ChaseDB//test\images\Image_14L.jpg (700, 700, 1050, 1050)
# All_3//ChaseDB//test\images\Image_14R.jpg (0, 0, 350, 350)
# All_3//ChaseDB//test\images\Image_14R.jpg (0, 350, 350, 700)
# All_3//ChaseDB//test\images\Image_14R.jpg (0, 700, 350, 1050)
# All_3//ChaseDB//test\images\Image_14R.jpg (350, 0, 700, 350)
# All_3//ChaseDB//test\images\Image_14R.jpg (350, 350, 700, 700)
# All_3//ChaseDB//test\images\Image_14R.jpg (350, 700, 700, 1050)
# All_3//ChaseDB//test\images\Image_14R.jpg (700, 0, 1050, 350)
# All_3//ChaseDB//test\images\Image_14R.jpg (700, 350, 1050, 700)
# All_3//ChaseDB//test\images\Image_14R.jpg (700, 700, 1050, 1050)

# %%
PATH_HRF= 'All_3//HRF//test'

# %%
t_images_HRF=glob.glob(os.path.join(PATH_HRF,'images','*.jpg'))

# %%
src = "./All_3/HRF/test/images/"
dst = "./All_3/test/output_images/"

# %%
cropheight=900
cropwidth = 600
k=-1
for file in t_images_HRF:
    k+=1
    im = Image.open(t_images_HRF[k])
    width, height = im.size
    for i in range(0, width, cropwidth):
     for j in range(0, height, cropheight): 
       box = (i, j,i+cropwidth, j+cropheight)
       print('%s %s' % (t_images_HRF[k], box))
       im.crop(box).save('%s.width%03d.height%03d.tiff' % (t_images_HRF[k], i, j))
       files = [i for i in os.listdir(src) if i.endswith(".tiff") and path.isfile(path.join(src, i))]
       for f in files:
        shutil.move(path.join(src, f), dst)
# Out:
# All_3//HRF//test\images\15_dr.JPG (0, 0, 600, 900)
# All_3//HRF//test\images\15_dr.JPG (0, 900, 600, 1800)
# All_3//HRF//test\images\15_dr.JPG (0, 1800, 600, 2700)
# All_3//HRF//test\images\15_dr.JPG (600, 0, 1200, 900)
# All_3//HRF//test\images\15_dr.JPG (600, 900, 1200, 1800)
# All_3//HRF//test\images\15_dr.JPG (600, 1800, 1200, 2700)
# All_3//HRF//test\images\15_dr.JPG (1200, 0, 1800, 900)
# All_3//HRF//test\images\15_dr.JPG (1200, 900, 1800, 1800)
# All_3//HRF//test\images\15_dr.JPG (1200, 1800, 1800, 2700)
# All_3//HRF//test\images\15_dr.JPG (1800, 0, 2400, 900)
# All_3//HRF//test\images\15_dr.JPG (1800, 900, 2400, 1800)
# All_3//HRF//test\images\15_dr.JPG (1800, 1800, 2400, 2700)
# All_3//HRF//test\images\15_dr.JPG (2400, 0, 3000, 900)
# All_3//HRF//test\images\15_dr.JPG (2400, 900, 3000, 1800)
# All_3//HRF//test\images\15_dr.JPG (2400, 1800, 3000, 2700)
# All_3//HRF//test\images\15_dr.JPG (3000, 0, 3600, 900)
# All_3//HRF//test\images\15_dr.JPG (3000, 900, 3600, 1800)
# All_3//HRF//test\images\15_dr.JPG (3000, 1800, 3600, 2700)
# All_3//HRF//test\images\15_g.jpg (0, 0, 600, 900)
# All_3//HRF//test\images\15_g.jpg (0, 900, 600, 1800)
# All_3//HRF//test\images\15_g.jpg (0, 1800, 600, 2700)
# All_3//HRF//test\images\15_g.jpg (600, 0, 1200, 900)
# All_3//HRF//test\images\15_g.jpg (600, 900, 1200, 1800)
# All_3//HRF//test\images\15_g.jpg (600, 1800, 1200, 2700)
# All_3//HRF//test\images\15_g.jpg (1200, 0, 1800, 900)
# All_3//HRF//test\images\15_g.jpg (1200, 900, 1800, 1800)
# All_3//HRF//test\images\15_g.jpg (1200, 1800, 1800, 2700)
# All_3//HRF//test\images\15_g.jpg (1800, 0, 2400, 900)
# All_3//HRF//test\images\15_g.jpg (1800, 900, 2400, 1800)
# All_3//HRF//test\images\15_g.jpg (1800, 1800, 2400, 2700)
# All_3//HRF//test\images\15_g.jpg (2400, 0, 3000, 900)
# All_3//HRF//test\images\15_g.jpg (2400, 900, 3000, 1800)
# All_3//HRF//test\images\15_g.jpg (2400, 1800, 3000, 2700)
# All_3//HRF//test\images\15_g.jpg (3000, 0, 3600, 900)
# All_3//HRF//test\images\15_g.jpg (3000, 900, 3600, 1800)
# All_3//HRF//test\images\15_g.jpg (3000, 1800, 3600, 2700)
# All_3//HRF//test\images\15_h.jpg (0, 0, 600, 900)
# All_3//HRF//test\images\15_h.jpg (0, 900, 600, 1800)
# All_3//HRF//test\images\15_h.jpg (0, 1800, 600, 2700)
# All_3//HRF//test\images\15_h.jpg (600, 0, 1200, 900)
# All_3//HRF//test\images\15_h.jpg (600, 900, 1200, 1800)
# All_3//HRF//test\images\15_h.jpg (600, 1800, 1200, 2700)
# All_3//HRF//test\images\15_h.jpg (1200, 0, 1800, 900)
# All_3//HRF//test\images\15_h.jpg (1200, 900, 1800, 1800)
# All_3//HRF//test\images\15_h.jpg (1200, 1800, 1800, 2700)
# All_3//HRF//test\images\15_h.jpg (1800, 0, 2400, 900)
# All_3//HRF//test\images\15_h.jpg (1800, 900, 2400, 1800)
# All_3//HRF//test\images\15_h.jpg (1800, 1800, 2400, 2700)
# All_3//HRF//test\images\15_h.jpg (2400, 0, 3000, 900)
# All_3//HRF//test\images\15_h.jpg (2400, 900, 3000, 1800)
# All_3//HRF//test\images\15_h.jpg (2400, 1800, 3000, 2700)
# All_3//HRF//test\images\15_h.jpg (3000, 0, 3600, 900)
# All_3//HRF//test\images\15_h.jpg (3000, 900, 3600, 1800)
# All_3//HRF//test\images\15_h.jpg (3000, 1800, 3600, 2700)

# %%
PATH2 = 'All_3//test'

# %%
t_images=glob.glob(os.path.join(PATH2,'output_images','*.tiff'))

# %%
test_images=np.array([get_data(path) for path in t_images])
test_images.shape
# Out:
# (252, 128, 128)

# %%
plt.imshow(test_images[0])

# %%
test_images.shape
# Out:
# (252, 128, 128, 1)

# %%
test_images = test_images / 255

# %%
imgs_mask_test = model.predict(test_images, verbose=1)
# Out:
# 252/252 [==============================] - 8s 31ms/step

# %%
idx = random.randint(0, len(imgs_mask_test))
i = imgs_mask_test[idx]
i = i[:, :, 0]
i.shape
plt.imshow(i, cmap='gray')
plt.imsave('filename.png', i, cmap='gray')

# %%
yp = np.round(imgs_mask_test,0)

# %%
idx = random.randint(0, len(yp))
i = imgs_mask_test[idx]
i = i[:, :, 0]
i.shape
# Out:
# (128, 128)

# %%
plt.imshow(i, cmap='gray')

# %% [markdown]
# #####
